# %%
import pandas as pd # conda install pandas
import plotly.express as px # conda install plotly
import datetime

# %%
df = pd.read_csv("posts.csv")
df.created_at = pd.to_datetime(df["created_at"]).dt.date
df
# Out:
#                                      title  \
# 0          The many verse drips moonlight.
# 1     Versed inevitable accomplishes sale.
# 2               A damp pusher mates purse.
# 3      The racial rap processes semantics.
# 4    An oceanic playground risks patience.
# ..                                     ...
# 95       The squeamish morale fights flow.
# 96        The black codon signals linkage.
# 97    An exuberant pillow costs condition.
# 98      A concerned clover radiates dolor.
# 99  Youthful balloonist overdraws trainer.
#
#                                                  body  created_at  \
# 0   The charming teapot permits decoder.\nA domine...  2025-11-02
# 1   The tart kick pauses bobcat.\nThe clammy rowin...  2025-11-02
# 2   A cooing bud invents off-ramp.\nA hurt fedora ...  2025-11-03
# 3   Grouchy plain complains clone.\nThe subdued ri...  2025-10-28
# 4   A wasteful heartwood questions budget.\nRobust...  2025-10-28
# ..                                                ...         ...
# 95  The lowly tolerance specifies pool.\nThe draco...  2025-10-29
# 96  The ethereal neuron pushes journalism.\nThe ri...  2025-10-30
# 97  The hesitant impediment amuses ex-wife.\nThe h...  2025-11-06
# 98  The earsplitting spit yells dragster.\nThe war...  2025-11-04
# 99  The abaft elderberry curves sunglasses.\nThe t...  2025-11-03
#
#                author
# 0      Lina DJARMOUNI
# 1    Christian HEROLD
# 2      Lina DJARMOUNI
# 3      Lina DJARMOUNI
# 4         Lukas GREVE
# ..                ...
# 95     Harald WENDLER
# 96   Christian HEROLD
# 97  Takahiro TAKEUCHI
# 98      Malik KARAOUI
# 99     Harald WENDLER
#
# [100 rows x 4 columns]

# %%
post_per_day = df.groupby("created_at").size()
post_per_day
# Out:
# created_at
# 2025-10-28    14
# 2025-10-29     9
# 2025-10-30    13
# 2025-10-31     6
# 2025-11-01    15
# 2025-11-02     9
# 2025-11-03    10
# 2025-11-04     8
# 2025-11-05     7
# 2025-11-06     9
# dtype: int64

# %%
post_per_date_bar = px.bar(post_per_day)
post_per_date_bar
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/miniforge3/envs/nomades_flask_312/lib/python3.12/site-packages/IPython/core/formatters.py:984, in IPythonDisplayFormatter.__call__(self, obj)
#     982 method = get_real_method(obj, self.print_method)
#     983 if method is not None:
# --> 984     method()
#     985     return True
#
# File ~/miniforge3/envs/nomades_flask_312/lib/python3.12/site-packages/plotly/basedatatypes.py:850, in BaseFigure._ipython_display_(self)
#     847 import plotly.io as pio
#     849 if pio.renderers.render_on_display and pio.renderers.default:
# --> 850     pio.show(self)
#     851 else:
#     852     print(repr(self))
#
# File ~/miniforge3/envs/nomades_flask_312/lib/python3.12/site-packages/plotly/io/_renderers.py:415, in show(fig, renderer, validate, **kwargs)
#     410     raise ValueError(
#     411         "Mime type rendering requires ipython but it is not installed"
#     412     )
#     414 if not nbformat or Version(nbformat.__version__) < Version("4.2.0"):
# --> 415     raise ValueError(
#     416         "Mime type rendering requires nbformat>=4.2.0 but it is not installed"
#     417     )
#     419 display_jupyter_version_warnings()
#     421 ipython_display.display(bundle, raw=True)
#
# ValueError: Mime type rendering requires nbformat>=4.2.0 but it is not installed
# Figure({
#     'data': [{'hovertemplate': 'variable=0<br>created_at=%{x}<br>value=%{y}<extra></extra>',
#               'legendgroup': '0',
#               'marker': {'color': '#636efa', 'pattern': {'shape': ''}},
#               'name': '0',
#               'orientation': 'v',
#               'showlegend': True,
#               'textposition': 'auto',
#               'type': 'bar',
#               'x': array([datetime.date(2025, 10, 28), datetime.date(2025, 10, 29),
#                           datetime.date(2025, 10, 30), datetime.date(2025, 10, 31),
#                           datetime.date(2025, 11, 1), datetime.date(2025, 11, 2),
#                           datetime.date(2025, 11, 3), datetime.date(2025, 11, 4),
#                           datetime.date(2025, 11, 5), datetime.date(2025, 11, 6)], dtype=object),
#               'xaxis': 'x',
#               'y': {'bdata': 'DgkNBg8JCggHCQ==', 'dtype': 'i1'},
#               'yaxis': 'y'}],
#     'layout': {'barmode': 'relative',
#                'legend': {'title': {'text': 'variable'}, 'tracegroupgap': 0},
#                'margin': {'t': 60},
#                'template': '...',
#                'xaxis': {'anchor': 'y', 'domain': [0.0, 1.0], 'title': {'text': 'created_at'}},
#                'yaxis': {'anchor': 'x', 'domain': [0.0, 1.0], 'title': {'text': 'value'}}}
# })

# %%
authors = df_filtered.author.unique()
authors

# %%
post_per_author = df_filtered.loc[df_filtered.created_at.between(datetime.date(2025, 6, 1), datetime.date(2025, 6, 1))].groupby("author").size()
post_per_author

# %%
post_per_authors_and_date = df.groupby(["created_at", "author"]).size()
post_per_authors_and_date.plot.bar()

# %%
post_per_authors_date_bar = px.bar(
  post_per_authors_and_date, 
  x=post_per_authors_and_date.index.get_level_values(0), 
  y=post_per_authors_and_date.values, 
  color=post_per_authors_and_date.index.get_level_values(1)
)
post_per_authors_date_bar
