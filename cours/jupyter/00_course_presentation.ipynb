# %% [markdown]
# # Python Software Engineer
# ## Welcome to the course!
#
# ### Antonio Pisanello | PPL_2026_4T - Nomades

# %% [markdown]
# # Présentation du cours
#
# - semaine 1: Python, les bases
# - semaine 2: Python, POO
# - semaine 3: NumPy & Pandas
# - semaine 4: Flask web (plateform)
# - semaine 5: Flask avancé

# %% [markdown]
# # Présentation
#
# - Antonio Pisanello
# - Freelance depuis 4,5 ans
# - Programmation et Sport
# - [Contactez moi par e-mail](mailto:antonio@apisanello.dev)
# - [Mon site web](https://apisanello.dev)
# - À vous :)

# %% [markdown]
# # Questions ?

# %% [markdown]
# # Bon Cours :)
