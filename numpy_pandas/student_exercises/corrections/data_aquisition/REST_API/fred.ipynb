# %% [markdown]
# # Fred aquisition data

# %%
import json
import matplotlib.pyplot as plt
import requests

# %%
# Load the secret api key
with open('api_creds.json', 'r') as f:
    secrets = json.load(f)

api_key = secrets['api_key'] # you can hardcode your value here if you want
api_key
# Out:
# '81a93c5dbf89810297e0b62325fd00b7'

# %% [markdown]
# ### Some example without Pandas

# %%
seriesID = "UNRATE"   # Unemployment rate
start = "2015-01-01"  # start date
end = "2023-10-31"    # end date
units = "pc1"         # Percent change from a year ago

url = "https://api.stlouisfed.org/fred/series/observations" + \
      f"?series_id={seriesID}&api_key={api_key}&file_type=json" + \
      f"&observation_start={start}&observation_end={end}&units={units}"
print(url)
response = requests.get(url)

# print the response
print("response :", response)
# Out:
# https://api.stlouisfed.org/fred/series/observations?series_id=UNRATE&api_key=81a93c5dbf89810297e0b62325fd00b7&file_type=json&observation_start=2015-01-01&observation_end=2023-10-31&units=pc1
# response : <Response [200]>

# %% [markdown]
# Here the response is <Response [200]> which means that the request was successful.
# 200 is the status code for a successful request.

# %%
# print the status code
print("status code :", response.status_code)

# print the content
print("content :", type(response.content))
# Out:
#   Cell In[60], line 2
#     print("status code :", response?gdp.status_code)
#                                    ^
# SyntaxError: invalid syntax

# %% [markdown]
# Here the content is in byte format.
# We can decode it to utf-8 format.
# But, as the reposnse is in json format,
# we can directly decode it to json format using the json() method from requests library

# %%
# print the json content
print("json content :", response.json())
# Out:
# json content : {'realtime_start': '2026-05-05', 'realtime_end': '2026-05-05', 'observation_start': '2015-01-01', 'observation_end': '2023-10-31', 'units': 'pc1', 'output_type': 1, 'file_type': 'json', 'order_by': 'observation_date', 'sort_order': 'asc', 'count': 106, 'offset': 0, 'limit': 100000, 'observations': [{'realtime_start': '2026-05-05', 'realtime_end': '2026-05-05', 'date': '2015-01-01', 'value': '-13.63636'}, {'realtime_start': '2026-05-05', 'realtime_end': '2026-05-05', 'date': '2015-02-01', 'value': '-17.91045'}, {'realtime_start': '2026-05-05', 'realtime_end': '2026-05-05', 'date': '2015-03-01', 'value': '-19.40299'}, {'realtime_start': '2026-05-05', 'realtime_end': '2026-05-05', 'date': '2015-04-01', 'value': '-12.90323'}, {'realtime_start': '2026-05-05', 'realtime_end': '2026-05-05', 'date': '2015-05-01', 'value': '-11.11111'}, {'realtime_start': '2026-05-05', 'realtime_end': '2026-05-05', 'date': '2015-06-01', 'value': '-13.11475'}, {'realtime_start': '2026-05-05', 'realtime_end': '2026-05-05', 'date': '2015-07-01', 'value': '-16.12903'}, {'realtime_start': '2026-05-05', 'realtime_end': '2026-05-05', 'date': '2015-08-01', 'value': '-16.39344'}, {'realtime_start': '2026-05-05', 'realtime_end': '2026-05-05', 'date': '2015-09-01', 'value': '-15.25424'}, {'realtime_start': '2026-05-05', 'realtime_end': '2026-05-05', 'date': '2015-10-01', 'value': '-12.28070'}, {'realtime_start': '2026-05-05', 'realtime_end': '2026-05-05', 'date': '2015-11-01', 'value': '-12.06897'}, {'realtime_start': '2026-05-05', 'realtime_end': '2026-05-05', 'date': '2015-12-01', 'value': '-10.71429'}, {'realtime_start': '2026-05-05', 'realtime_end': '2026-05-05', 'date': '2016-01-01', 'value': '-15.78947'}, {'realtime_start': '2026-05-05', 'realtime_end': '2026-05-05', 'date': '2016-02-01', 'value': '-10.90909'}, {'realtime_start': '2026-05-05', 'realtime_end': '2026-05-05', 'date': '2016-03-01', 'value': '-7.40741'}, {'realtime_start': '2026-05-05', 'realtime_end': '2026-05-05', 'date': '2016-04-01', 'value': '-5.55556'}, {'realtime_start': '2026-05-05', 'realtime_end': '2026-05-05', 'date': '2016-05-01', 'value': '-14.28571'}, {'realtime_start': '2026-05-05', 'realtime_end': '2026-05-05', 'date': '2016-06-01', 'value': '-7.54717'}, {'realtime_start': '2026-05-05', 'realtime_end': '2026-05-05', 'date': '2016-07-01', 'value': '-7.69231'}, {'realtime_start': '2026-05-05', 'realtime_end': '2026-05-05', 'date': '2016-08-01', 'value': '-3.92157'}, {'realtime_start': '2026-05-05', 'realtime_end': '2026-05-05', 'date': '2016-09-01', 'value': '0.00000'}, {'realtime_start': '2026-05-05', 'realtime_end': '2026-05-05', 'date': '2016-10-01', 'value': '-2.00000'}, {'realtime_start': '2026-05-05', 'realtime_end': '2026-05-05', 'date': '2016-11-01', 'value': '-7.84314'}, {'realtime_start': '2026-05-05', 'realtime_end': '2026-05-05', 'date': '2016-12-01', 'value': '-6.00000'}, {'realtime_start': '2026-05-05', 'realtime_end': '2026-05-05', 'date': '2017-01-01', 'value': '-2.08333'}, {'realtime_start': '2026-05-05', 'realtime_end': '2026-05-05', 'date': '2017-02-01', 'value': '-6.12245'}, {'realtime_start': '2026-05-05', 'realtime_end': '2026-05-05', 'date': '2017-03-01', 'value': '-12.00000'}, {'realtime_start': '2026-05-05', 'realtime_end': '2026-05-05', 'date': '2017-04-01', 'value': '-13.72549'}, {'realtime_start': '2026-05-05', 'realtime_end': '2026-05-05', 'date': '2017-05-01', 'value': '-8.33333'}, {'realtime_start': '2026-05-05', 'realtime_end': '2026-05-05', 'date': '2017-06-01', 'value': '-12.24490'}, {'realtime_start': '2026-05-05', 'realtime_end': '2026-05-05', 'date': '2017-07-01', 'value': '-10.41667'}, {'realtime_start': '2026-05-05', 'realtime_end': '2026-05-05', 'date': '2017-08-01', 'value': '-10.20408'}, {'realtime_start': '2026-05-05', 'realtime_end': '2026-05-05', 'date': '2017-09-01', 'value': '-14.00000'}, {'realtime_start': '2026-05-05', 'realtime_end': '2026-05-05', 'date': '2017-10-01', 'value': '-14.28571'}, {'realtime_start': '2026-0 ...

# %% [markdown]
# The json response contains some keys like:
#   - realtime_start
#   - realtime_end
#   - units
#   ...
#   - observations
#
# The observations key contains the data we need.
# The observation key contains a list of dictionaries. where two keys are interesting for us:
#   - date, the date of the observation
#   - value, the value of the observation

# %%
# Given the response in json format, extract a list made of tuples where the first element is the date as str type and the second element is the value as float type
# Hint: use list comprehension
# FRED API Observations DOC : https://fred.stlouisfed.org/docs/api/fred/series_observations.html
# data: list[tuple[str, float]] = []

# for observation in response.json()["observations"]:
#   data.append((observation["date"], float(observation["value"])))

data: list[tuple[str, float]] = [(observation["date"], float(observation["value"])) for observation in response.json()["observations"]]
print("data :", data)
# Out:
# data : [('2015-01-01', -13.63636), ('2015-02-01', -17.91045), ('2015-03-01', -19.40299), ('2015-04-01', -12.90323), ('2015-05-01', -11.11111), ('2015-06-01', -13.11475), ('2015-07-01', -16.12903), ('2015-08-01', -16.39344), ('2015-09-01', -15.25424), ('2015-10-01', -12.2807), ('2015-11-01', -12.06897), ('2015-12-01', -10.71429), ('2016-01-01', -15.78947), ('2016-02-01', -10.90909), ('2016-03-01', -7.40741), ('2016-04-01', -5.55556), ('2016-05-01', -14.28571), ('2016-06-01', -7.54717), ('2016-07-01', -7.69231), ('2016-08-01', -3.92157), ('2016-09-01', 0.0), ('2016-10-01', -2.0), ('2016-11-01', -7.84314), ('2016-12-01', -6.0), ('2017-01-01', -2.08333), ('2017-02-01', -6.12245), ('2017-03-01', -12.0), ('2017-04-01', -13.72549), ('2017-05-01', -8.33333), ('2017-06-01', -12.2449), ('2017-07-01', -10.41667), ('2017-08-01', -10.20408), ('2017-09-01', -14.0), ('2017-10-01', -14.28571), ('2017-11-01', -10.6383), ('2017-12-01', -12.76596), ('2018-01-01', -14.89362), ('2018-02-01', -10.86957), ('2018-03-01', -9.09091), ('2018-04-01', -9.09091), ('2018-05-01', -13.63636), ('2018-06-01', -6.97674), ('2018-07-01', -11.62791), ('2018-08-01', -13.63636), ('2018-09-01', -13.95349), ('2018-10-01', -9.52381), ('2018-11-01', -9.52381), ('2018-12-01', -4.87805), ('2019-01-01', 0.0), ('2019-02-01', -7.31707), ('2019-03-01', -5.0), ('2019-04-01', -7.5), ('2019-05-01', -5.26316), ('2019-06-01', -10.0), ('2019-07-01', -2.63158), ('2019-08-01', -5.26316), ('2019-09-01', -5.40541), ('2019-10-01', -5.26316), ('2019-11-01', -5.26316), ('2019-12-01', -7.69231), ('2020-01-01', -10.0), ('2020-02-01', -7.89474), ('2020-03-01', 15.78947), ('2020-04-01', 300.0), ('2020-05-01', 266.66667), ('2020-06-01', 205.55556), ('2020-07-01', 175.67568), ('2020-08-01', 133.33333), ('2020-09-01', 122.85714), ('2020-10-01', 91.66667), ('2020-11-01', 86.11111), ('2020-12-01', 86.11111), ('2021-01-01', 77.77778), ('2021-02-01', 77.14286), ('2021-03-01', 38.63636), ('2021-04-01', -58.78378), ('2021-05-01', -56.06061), ('2021-06-01', -46.36364), ('2021-07-01', -47.05882), ('2021-08-01', -39.28571), ('2021-09-01', -39.74359), ('2021-10-01', -34.78261), ('2021-11-01', -38.80597), ('2021-12-01', -41.79104), ('2022-01-01', -37.5), ('2022-02-01', -37.09677), ('2022-03-01', -39.34426), ('2022-04-01', -39.34426), ('2022-05-01', -37.93103), ('2022-06-01', -38.98305), ('2022-07-01', -35.18519), ('2022-08-01', -29.41176), ('2022-09-01', -25.53191), ('2022-10-01', -20.0), ('2022-11-01', -12.19512), ('2022-12-01', -10.25641), ('2023-01-01', -12.5), ('2023-02-01', -7.69231), ('2023-03-01', -5.40541), ('2023-04-01', -8.10811), ('2023-05-01', 0.0), ('2023-06-01', 0.0), ('2023-07-01', 0.0), ('2023-08-01', 2.77778), ('2023-09-01', 5.71429), ('2023-10-01', 8.33333)]

# %%
# Plotting the data
# plot the data, you need to create the same plot as the one following

X = [obs[0] for obs in data]
Y = [y for _, y in data]

plt.plot(X, Y, label="Unemployment Rate")

plt.xlabel("Date")
plt.ylabel("PC1")
plt.legend()
plt.title("Unemployment Rate from 2015 to 2023")

plt.xticks(X[::6], rotation=90)

plt.show()

# %%
# from example_plot import example_plot
# x = None
# y = None
# example_plot(x, y, u"Unemployment rate")
# I changed the plt.xticks to display only one date per year and changed the reotation to 90degree

# %% [markdown]
# # Part 2: two plots
# In this part you are required to make one chart with two plots, one for the `GDP` and one for the `UNRATE`.
#
# This tie you are asked to make the API calls by yourself (you can inspire yourself from the previous part). You can keep the same start and end date, but the seriesID should be different (`GDP` and `UNRATE` respectivelly). The units also differs:
# - for `GDP` the units would be `pc1`
# - for `UNRATE` the units would be `lin`
#
# Once you have the data you should plot the inside the same chart. You'll use the same values for `X` and the `Y` values will differs for the two plots.

# %%
import pandas as pd

# %%
seriesID = "GDP"   # Unemployment rate
units = "pc1"         # Percent change from a year ago

url = "https://api.stlouisfed.org/fred/series/observations" + \
      f"?series_id={seriesID}&api_key={api_key}&file_type=json" + \
      f"&observation_start={start}&observation_end={end}&units={units}"
print(url)
response_gdp = requests.get(url)

# print the response
print("response :", response_gdp)
# Out:
# https://api.stlouisfed.org/fred/series/observations?series_id=GDP&api_key=81a93c5dbf89810297e0b62325fd00b7&file_type=json&observation_start=2015-01-01&observation_end=2023-10-31&units=pc1
# response : <Response [200]>

# %%
seriesID = "UNRATE"   # Unemployment rate
units = "lin"         # Percent change from a year ago

url = "https://api.stlouisfed.org/fred/series/observations" + \
      f"?series_id={seriesID}&api_key={api_key}&file_type=json" + \
      f"&observation_start={start}&observation_end={end}&units={units}"
print(url)
response_unrate = requests.get(url)

# print the response
print("response :", response_unrate)
# Out:
# https://api.stlouisfed.org/fred/series/observations?series_id=UNRATE&api_key=81a93c5dbf89810297e0b62325fd00b7&file_type=json&observation_start=2015-01-01&observation_end=2023-10-31&units=lin
# response : <Response [200]>

# %%
gdp_df: pd.DataFrame = pd.DataFrame(response_gdp.json()["observations"]).loc[:, ["date", "value"]]
gdp_df["value"] = gdp_df["value"].astype(float)

# %%
unrate_df = pd.DataFrame(response_unrate.json()["observations"]).loc[:, ["date", "value"]]
unrate_df.value = unrate_df.value.astype(float)

# %%
plt.plot(unrate_df.date, unrate_df.value, label="Unemployment Rate")
plt.plot(gdp_df.date, gdp_df.value, label="GDP")

plt.legend()

plt.title("Unemployment rate VS GDP")
plt.xlabel("Year")

plt.xticks(
  unrate_df.date.loc[::12], 
  labels=unrate_df.date.loc[::12].map(lambda date_str: date_str[:4])
)

plt.show()
