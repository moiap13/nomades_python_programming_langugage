# %% [markdown]
# # Fred aquisition data

# %%
import json
import matplotlib.pyplot as plt
import requests

# %%
# Load the secret api key
with open('api_creds.json', 'r') as f:
    secrets: dict[str, str] = json.load(f)

api_key: str = secrets['api_key'] # you can hardcode your value here if you want
api_key
# Out:
# '81a93c5dbf89810297e0b62325fd00b7'

# %% [markdown]
# ### Some example without Pandas

# %%
seriesID = "UNRATE"   # Unemployment rate
start = "2015-01-01"  # start date
end = "2023-10-31"    # end date
units = "pc1"         # Percent change from a year ago

url = "https://api.stlouisfed.org/fred/series/observations" + \
      f"?series_id={seriesID}&api_key={api_key}&file_type=json" + \
      f"&observation_start={start}&observation_end={end}&units={units}"
print(url)
response = requests.get(url)

# print the response
print("response :", response)
# Out:
# https://api.stlouisfed.org/fred/series/observations?series_id=UNRATE&api_key=81a93c5dbf89810297e0b62325fd00b7&file_type=json&observation_start=2015-01-01&observation_end=2023-10-31&units=pc1
# response : <Response [200]>

# %% [markdown]
# Here the response is <Response [200]> which means that the request was successful.
# 200 is the status code for a successful request.

# %%
# print the status code
print("status code :", response.status_code)

# print the content
print("content :", (response.content))
# Out:
# status code : 200
# content : b'{"realtime_start":"2026-07-21","realtime_end":"2026-07-21","observation_start":"2015-01-01","observation_end":"2023-10-31","units":"pc1","output_type":1,"file_type":"json","order_by":"observation_date","sort_order":"asc","count":106,"offset":0,"limit":100000,"observations":[{"realtime_start":"2026-07-21","realtime_end":"2026-07-21","date":"2015-01-01","value":"-13.63636"},{"realtime_start":"2026-07-21","realtime_end":"2026-07-21","date":"2015-02-01","value":"-17.91045"},{"realtime_start":"2026-07-21","realtime_end":"2026-07-21","date":"2015-03-01","value":"-19.40299"},{"realtime_start":"2026-07-21","realtime_end":"2026-07-21","date":"2015-04-01","value":"-12.90323"},{"realtime_start":"2026-07-21","realtime_end":"2026-07-21","date":"2015-05-01","value":"-11.11111"},{"realtime_start":"2026-07-21","realtime_end":"2026-07-21","date":"2015-06-01","value":"-13.11475"},{"realtime_start":"2026-07-21","realtime_end":"2026-07-21","date":"2015-07-01","value":"-16.12903"},{"realtime_start":"2026-07-21","realtime_end":"2026-07-21","date":"2015-08-01","value":"-16.39344"},{"realtime_start":"2026-07-21","realtime_end":"2026-07-21","date":"2015-09-01","value":"-15.25424"},{"realtime_start":"2026-07-21","realtime_end":"2026-07-21","date":"2015-10-01","value":"-12.28070"},{"realtime_start":"2026-07-21","realtime_end":"2026-07-21","date":"2015-11-01","value":"-12.06897"},{"realtime_start":"2026-07-21","realtime_end":"2026-07-21","date":"2015-12-01","value":"-10.71429"},{"realtime_start":"2026-07-21","realtime_end":"2026-07-21","date":"2016-01-01","value":"-15.78947"},{"realtime_start":"2026-07-21","realtime_end":"2026-07-21","date":"2016-02-01","value":"-10.90909"},{"realtime_start":"2026-07-21","realtime_end":"2026-07-21","date":"2016-03-01","value":"-7.40741"},{"realtime_start":"2026-07-21","realtime_end":"2026-07-21","date":"2016-04-01","value":"-5.55556"},{"realtime_start":"2026-07-21","realtime_end":"2026-07-21","date":"2016-05-01","value":"-14.28571"},{"realtime_start":"2026-07-21","realtime_end":"2026-07-21","date":"2016-06-01","value":"-7.54717"},{"realtime_start":"2026-07-21","realtime_end":"2026-07-21","date":"2016-07-01","value":"-7.69231"},{"realtime_start":"2026-07-21","realtime_end":"2026-07-21","date":"2016-08-01","value":"-3.92157"},{"realtime_start":"2026-07-21","realtime_end":"2026-07-21","date":"2016-09-01","value":"0.00000"},{"realtime_start":"2026-07-21","realtime_end":"2026-07-21","date":"2016-10-01","value":"-2.00000"},{"realtime_start":"2026-07-21","realtime_end":"2026-07-21","date":"2016-11-01","value":"-7.84314"},{"realtime_start":"2026-07-21","realtime_end":"2026-07-21","date":"2016-12-01","value":"-6.00000"},{"realtime_start":"2026-07-21","realtime_end":"2026-07-21","date":"2017-01-01","value":"-2.08333"},{"realtime_start":"2026-07-21","realtime_end":"2026-07-21","date":"2017-02-01","value":"-6.12245"},{"realtime_start":"2026-07-21","realtime_end":"2026-07-21","date":"2017-03-01","value":"-12.00000"},{"realtime_start":"2026-07-21","realtime_end":"2026-07-21","date":"2017-04-01","value":"-13.72549"},{"realtime_start":"2026-07-21","realtime_end":"2026-07-21","date":"2017-05-01","value":"-8.33333"},{"realtime_start":"2026-07-21","realtime_end":"2026-07-21","date":"2017-06-01","value":"-12.24490"},{"realtime_start":"2026-07-21","realtime_end":"2026-07-21","date":"2017-07-01","value":"-10.41667"},{"realtime_start":"2026-07-21","realtime_end":"2026-07-21","date":"2017-08-01","value":"-10.20408"},{"realtime_start":"2026-07-21","realtime_end":"2026-07-21","date":"2017-09-01","value":"-14.00000"},{"realtime_start":"2026-07-21","realtime_end":"2026-07-21","date":"2017-10-01","value":"-14.28571"},{"realtime_start":"2026-07-21","realtime_end":"2026-07-21","date":"2017-11-01","value":"-10.63830"},{"realtime_start":"2026-07-21","realtime_end":"2026-07-21","date":"2017-12-01","value":"-12.76596"},{"realtime_start":"2026-07-21","realtime_end":"2026-07-21","date":"2018-01-01","value":"-14.89362"},{"realtime_start":"2026-07 ...

# %%
response.text
# Out:
# '{"realtime_start":"2026-07-21","realtime_end":"2026-07-21","observation_start":"2015-01-01","observation_end":"2023-10-31","units":"pc1","output_type":1,"file_type":"json","order_by":"observation_date","sort_order":"asc","count":106,"offset":0,"limit":100000,"observations":[{"realtime_start":"2026-07-21","realtime_end":"2026-07-21","date":"2015-01-01","value":"-13.63636"},{"realtime_start":"2026-07-21","realtime_end":"2026-07-21","date":"2015-02-01","value":"-17.91045"},{"realtime_start":"2026-07-21","realtime_end":"2026-07-21","date":"2015-03-01","value":"-19.40299"},{"realtime_start":"2026-07-21","realtime_end":"2026-07-21","date":"2015-04-01","value":"-12.90323"},{"realtime_start":"2026-07-21","realtime_end":"2026-07-21","date":"2015-05-01","value":"-11.11111"},{"realtime_start":"2026-07-21","realtime_end":"2026-07-21","date":"2015-06-01","value":"-13.11475"},{"realtime_start":"2026-07-21","realtime_end":"2026-07-21","date":"2015-07-01","value":"-16.12903"},{"realtime_start":"2026-07-21","realtime_end":"2026-07-21","date":"2015-08-01","value":"-16.39344"},{"realtime_start":"2026-07-21","realtime_end":"2026-07-21","date":"2015-09-01","value":"-15.25424"},{"realtime_start":"2026-07-21","realtime_end":"2026-07-21","date":"2015-10-01","value":"-12.28070"},{"realtime_start":"2026-07-21","realtime_end":"2026-07-21","date":"2015-11-01","value":"-12.06897"},{"realtime_start":"2026-07-21","realtime_end":"2026-07-21","date":"2015-12-01","value":"-10.71429"},{"realtime_start":"2026-07-21","realtime_end":"2026-07-21","date":"2016-01-01","value":"-15.78947"},{"realtime_start":"2026-07-21","realtime_end":"2026-07-21","date":"2016-02-01","value":"-10.90909"},{"realtime_start":"2026-07-21","realtime_end":"2026-07-21","date":"2016-03-01","value":"-7.40741"},{"realtime_start":"2026-07-21","realtime_end":"2026-07-21","date":"2016-04-01","value":"-5.55556"},{"realtime_start":"2026-07-21","realtime_end":"2026-07-21","date":"2016-05-01","value":"-14.28571"},{"realtime_start":"2026-07-21","realtime_end":"2026-07-21","date":"2016-06-01","value":"-7.54717"},{"realtime_start":"2026-07-21","realtime_end":"2026-07-21","date":"2016-07-01","value":"-7.69231"},{"realtime_start":"2026-07-21","realtime_end":"2026-07-21","date":"2016-08-01","value":"-3.92157"},{"realtime_start":"2026-07-21","realtime_end":"2026-07-21","date":"2016-09-01","value":"0.00000"},{"realtime_start":"2026-07-21","realtime_end":"2026-07-21","date":"2016-10-01","value":"-2.00000"},{"realtime_start":"2026-07-21","realtime_end":"2026-07-21","date":"2016-11-01","value":"-7.84314"},{"realtime_start":"2026-07-21","realtime_end":"2026-07-21","date":"2016-12-01","value":"-6.00000"},{"realtime_start":"2026-07-21","realtime_end":"2026-07-21","date":"2017-01-01","value":"-2.08333"},{"realtime_start":"2026-07-21","realtime_end":"2026-07-21","date":"2017-02-01","value":"-6.12245"},{"realtime_start":"2026-07-21","realtime_end":"2026-07-21","date":"2017-03-01","value":"-12.00000"},{"realtime_start":"2026-07-21","realtime_end":"2026-07-21","date":"2017-04-01","value":"-13.72549"},{"realtime_start":"2026-07-21","realtime_end":"2026-07-21","date":"2017-05-01","value":"-8.33333"},{"realtime_start":"2026-07-21","realtime_end":"2026-07-21","date":"2017-06-01","value":"-12.24490"},{"realtime_start":"2026-07-21","realtime_end":"2026-07-21","date":"2017-07-01","value":"-10.41667"},{"realtime_start":"2026-07-21","realtime_end":"2026-07-21","date":"2017-08-01","value":"-10.20408"},{"realtime_start":"2026-07-21","realtime_end":"2026-07-21","date":"2017-09-01","value":"-14.00000"},{"realtime_start":"2026-07-21","realtime_end":"2026-07-21","date":"2017-10-01","value":"-14.28571"},{"realtime_start":"2026-07-21","realtime_end":"2026-07-21","date":"2017-11-01","value":"-10.63830"},{"realtime_start":"2026-07-21","realtime_end":"2026-07-21","date":"2017-12-01","value":"-12.76596"},{"realtime_start":"2026-07-21","realtime_end":"2026-07-21","date":"2018-01-01","value":"-14.89362"},{"realtime_start":"2026-07-21","realt ...

# %% [markdown]
# Here the content is in byte format.
# We can decode it to utf-8 format.
# But, as the reposnse is in json format,
# we can directly decode it to json format using the json() method from requests library

# %%
# print the json content
print("json content :", (response.json().keys()))
# Out:
# json content : dict_keys(['realtime_start', 'realtime_end', 'observation_start', 'observation_end', 'units', 'output_type', 'file_type', 'order_by', 'sort_order', 'count', 'offset', 'limit', 'observations'])

# %% [markdown]
# The json response contains some keys like:
#   - realtime_start
#   - realtime_end
#   - units
#   ...
#   - observations
#
# The observations key contains the data we need.
# The observation key contains a list of dictionaries. where two keys are interesting for us:
#   - date, the date of the observation
#   - value, the value of the observation

# %%
# Given the response in json format, extract a list made of tuples where the first element is the date as str type and the second element is the value as float type
# Hint: use list comprehension
# FRED API Observations DOC : https://fred.stlouisfed.org/docs/api/fred/series_observations.html
data: list[tuple[str, float]] = [(obs["date"], float(obs["value"])) for obs in response.json()["observations"]]
print("data :", (data))
# Out:
# data : [('2015-01-01', -13.63636), ('2015-02-01', -17.91045), ('2015-03-01', -19.40299), ('2015-04-01', -12.90323), ('2015-05-01', -11.11111), ('2015-06-01', -13.11475), ('2015-07-01', -16.12903), ('2015-08-01', -16.39344), ('2015-09-01', -15.25424), ('2015-10-01', -12.2807), ('2015-11-01', -12.06897), ('2015-12-01', -10.71429), ('2016-01-01', -15.78947), ('2016-02-01', -10.90909), ('2016-03-01', -7.40741), ('2016-04-01', -5.55556), ('2016-05-01', -14.28571), ('2016-06-01', -7.54717), ('2016-07-01', -7.69231), ('2016-08-01', -3.92157), ('2016-09-01', 0.0), ('2016-10-01', -2.0), ('2016-11-01', -7.84314), ('2016-12-01', -6.0), ('2017-01-01', -2.08333), ('2017-02-01', -6.12245), ('2017-03-01', -12.0), ('2017-04-01', -13.72549), ('2017-05-01', -8.33333), ('2017-06-01', -12.2449), ('2017-07-01', -10.41667), ('2017-08-01', -10.20408), ('2017-09-01', -14.0), ('2017-10-01', -14.28571), ('2017-11-01', -10.6383), ('2017-12-01', -12.76596), ('2018-01-01', -14.89362), ('2018-02-01', -10.86957), ('2018-03-01', -9.09091), ('2018-04-01', -9.09091), ('2018-05-01', -13.63636), ('2018-06-01', -6.97674), ('2018-07-01', -11.62791), ('2018-08-01', -13.63636), ('2018-09-01', -13.95349), ('2018-10-01', -9.52381), ('2018-11-01', -9.52381), ('2018-12-01', -4.87805), ('2019-01-01', 0.0), ('2019-02-01', -7.31707), ('2019-03-01', -5.0), ('2019-04-01', -7.5), ('2019-05-01', -5.26316), ('2019-06-01', -10.0), ('2019-07-01', -2.63158), ('2019-08-01', -5.26316), ('2019-09-01', -5.40541), ('2019-10-01', -5.26316), ('2019-11-01', -5.26316), ('2019-12-01', -7.69231), ('2020-01-01', -10.0), ('2020-02-01', -7.89474), ('2020-03-01', 15.78947), ('2020-04-01', 300.0), ('2020-05-01', 266.66667), ('2020-06-01', 205.55556), ('2020-07-01', 175.67568), ('2020-08-01', 133.33333), ('2020-09-01', 122.85714), ('2020-10-01', 91.66667), ('2020-11-01', 86.11111), ('2020-12-01', 86.11111), ('2021-01-01', 77.77778), ('2021-02-01', 77.14286), ('2021-03-01', 38.63636), ('2021-04-01', -58.78378), ('2021-05-01', -56.06061), ('2021-06-01', -46.36364), ('2021-07-01', -47.05882), ('2021-08-01', -39.28571), ('2021-09-01', -39.74359), ('2021-10-01', -34.78261), ('2021-11-01', -38.80597), ('2021-12-01', -41.79104), ('2022-01-01', -37.5), ('2022-02-01', -37.09677), ('2022-03-01', -39.34426), ('2022-04-01', -39.34426), ('2022-05-01', -37.93103), ('2022-06-01', -38.98305), ('2022-07-01', -35.18519), ('2022-08-01', -29.41176), ('2022-09-01', -25.53191), ('2022-10-01', -20.0), ('2022-11-01', -12.19512), ('2022-12-01', -10.25641), ('2023-01-01', -12.5), ('2023-02-01', -7.69231), ('2023-03-01', -5.40541), ('2023-04-01', -8.10811), ('2023-05-01', 0.0), ('2023-06-01', 0.0), ('2023-07-01', 0.0), ('2023-08-01', 2.77778), ('2023-09-01', 5.71429), ('2023-10-01', 8.33333)]

# %%
# Plotting the data
# plot the data, you need to create the same plot as the one following
x: list[str] = [t[0] for t in data]
y: list[float] = [v for _, v in data]

plt.plot(x, y, label='Unemployment rate')

plt.title("Unemployment rate from 2015 to 2023")
plt.xlabel("Date")
plt.ylabel("Percent change from 1 year ago")
plt.legend()

plt.xticks(x[::12], rotation=90)

plt.show()
# Out:
# ['2015-01-01', '2015-02-01', '2015-03-01', '2015-04-01', '2015-05-01', '2015-06-01', '2015-07-01', '2015-08-01', '2015-09-01', '2015-10-01', '2015-11-01', '2015-12-01', '2016-01-01', '2016-02-01', '2016-03-01', '2016-04-01', '2016-05-01', '2016-06-01', '2016-07-01', '2016-08-01', '2016-09-01', '2016-10-01', '2016-11-01', '2016-12-01', '2017-01-01', '2017-02-01', '2017-03-01', '2017-04-01', '2017-05-01', '2017-06-01', '2017-07-01', '2017-08-01', '2017-09-01', '2017-10-01', '2017-11-01', '2017-12-01', '2018-01-01', '2018-02-01', '2018-03-01', '2018-04-01', '2018-05-01', '2018-06-01', '2018-07-01', '2018-08-01', '2018-09-01', '2018-10-01', '2018-11-01', '2018-12-01', '2019-01-01', '2019-02-01', '2019-03-01', '2019-04-01', '2019-05-01', '2019-06-01', '2019-07-01', '2019-08-01', '2019-09-01', '2019-10-01', '2019-11-01', '2019-12-01', '2020-01-01', '2020-02-01', '2020-03-01', '2020-04-01', '2020-05-01', '2020-06-01', '2020-07-01', '2020-08-01', '2020-09-01', '2020-10-01', '2020-11-01', '2020-12-01', '2021-01-01', '2021-02-01', '2021-03-01', '2021-04-01', '2021-05-01', '2021-06-01', '2021-07-01', '2021-08-01', '2021-09-01', '2021-10-01', '2021-11-01', '2021-12-01', '2022-01-01', '2022-02-01', '2022-03-01', '2022-04-01', '2022-05-01', '2022-06-01', '2022-07-01', '2022-08-01', '2022-09-01', '2022-10-01', '2022-11-01', '2022-12-01', '2023-01-01', '2023-02-01', '2023-03-01', '2023-04-01', '2023-05-01', '2023-06-01', '2023-07-01', '2023-08-01', '2023-09-01', '2023-10-01']

# %%
from example_plot import example_plot
x = None
y = None
example_plot(x, y, u"Unemployment rate")
# I changed the plt.xticks to display only one date per year and changed the reotation to 90degree

# %% [markdown]
# # Part 2: two plots
# In this part you are required to make one chart with two plots, one for the `GDP` and one for the `UNRATE`.
#
# This tie you are asked to make the API calls by yourself (you can inspire yourself from the previous part). You can keep the same start and end date, but the seriesID should be different (`GDP` and `UNRATE` respectivelly). The units also differs:
# - for `GDP` the units would be `pc1`
# - for `UNRATE` the units would be `lin`
#
# Once you have the data you should plot the inside the same chart. You'll use the same values for `X` and the `Y` values will differs for the two plots.

# %%
seriesID = "GDP"   # Unemployment rate
units = "pc1"         # Percent change from a year ago

url = "https://api.stlouisfed.org/fred/series/observations" + \
      f"?series_id={seriesID}&api_key={api_key}&file_type=json" + \
      f"&observation_start={start}&observation_end={end}&units={units}"
print(url)
response_gdp = requests.get(url)

# print the response
print("response :", response_gdp)
# Out:
# https://api.stlouisfed.org/fred/series/observations?series_id=GDP&api_key=81a93c5dbf89810297e0b62325fd00b7&file_type=json&observation_start=2015-01-01&observation_end=2023-10-31&units=pc1
# response : <Response [200]>

# %%
seriesID = "UNRATE"   # Unemployment rate
units = "lin"         # Percent change from a year ago

url = "https://api.stlouisfed.org/fred/series/observations" + \
      f"?series_id={seriesID}&api_key={api_key}&file_type=json" + \
      f"&observation_start={start}&observation_end={end}&units={units}"
print(url)
response_unrate = requests.get(url)

# print the response
print("response :", response_unrate)
# Out:
# https://api.stlouisfed.org/fred/series/observations?series_id=UNRATE&api_key=81a93c5dbf89810297e0b62325fd00b7&file_type=json&observation_start=2015-01-01&observation_end=2023-10-31&units=lin
# response : <Response [200]>

# %%
import pandas as pd

# %%
gdp_df = pd.DataFrame(response_gdp.json()["observations"]).iloc[:, -2:]
# gdp_df = gdp_df.loc[:, ["date", "value"]]
gdp_df["value"] = gdp_df["value"].astype(float)
gdp_df
# Out:
#           date     value
# 0   2015-01-01   5.03433
# 1   2015-04-01   4.34555
# 2   2015-07-01   3.35537
# 3   2015-10-01   2.92014
# 4   2016-01-01   2.55988
# 5   2016-04-01   2.36282
# 6   2016-07-01   2.66831
# 7   2016-10-01   3.54889
# 8   2017-01-01   4.07079
# 9   2017-04-01   3.88495
# 10  2017-07-01   4.23422
# 11  2017-10-01   4.96459
# 12  2018-01-01   5.43809
# 13  2018-04-01   5.87628
# 14  2018-07-01   5.61701
# 15  2018-10-01   4.39574
# 16  2019-01-01   3.85196
# 17  2019-04-01   3.96982
# 18  2019-07-01   4.41585
# 19  2019-10-01   4.85398
# 20  2020-01-01   3.02979
# 21  2020-04-01  -6.72797
# 22  2020-07-01  -0.05864
# 23  2020-10-01   0.70187
# 24  2021-01-01   4.27311
# 25  2021-04-01  17.37433
# 26  2021-07-01  10.49528
# 27  2021-10-01  12.34400
# 28  2022-01-01  11.32970
# 29  2022-04-01  10.39610
# 30  2022-07-01   9.81523
# 31  2022-10-01   7.88646
# 32  2023-01-01   7.78642
# 33  2023-04-01   6.45274
# 34  2023-07-01   6.60131
# 35  2023-10-01   6.17922

# %%
unrate_df = pd.DataFrame(response_unrate.json()["observations"]).iloc[:, -2:]
unrate_df["value"] = unrate_df["value"].astype(float)
unrate_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 106 entries, 0 to 105
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    106 non-null    str
#  1   value   106 non-null    float64
# dtypes: float64(1), str(1)
# memory usage: 2.8 KB

# %%
plt.plot(unrate_df.date, unrate_df.value, label="Unemployment rate")
plt.plot(gdp_df["date"], gdp_df["value"], label="GDP")

plt.title("Unemployment rate vs GDP from 2015 to 2023")
plt.legend()
plt.xlabel("Date")

plt.xticks(unrate_df.date[::12], labels=[d[:4] for d in unrate_df.date[::12]])

plt.show()
